# %%
# !pip install -U keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2024.7.4)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import Sequential
import tensorflow as tf
from tensorflow.keras.layers import Dense
import keras_tuner as kf
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('https://raw.githubusercontent.com/aishwaryamate/Datasets/main/Churn_Modelling.csv')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df.drop(columns = ['RowNumber'	,'CustomerId',	'Surname'], inplace=True)

# %%
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
df = pd.get_dummies(data = df,columns=['Geography','Gender'], dtype = int)
df
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_France  \
# 0                  1        101348.88       1                 1
# 1                  1        112542.58       0                 0
# 2                  0        113931.57       1                 1
# 3                  0         93826.63       0                 1
# 4                  1         79084.10       0                 0
# ...              ...              ...     ...               ...
# 9995               0         96270.64       0                 1
# 9996               1        101699.77       0                 1
# 9997               1         42085.58       1                 1
# 9998               0         92888.52       1                 0
# 9999               0         38190.78       0                 1
#
#       Geography_Germany  Geography_Spain  Gender_Female  Gender_Male
# 0                     0                0              1            0
# 1                     0                1              1            0
# 2                     0                0              1            0
# 3                     0                0              1            0
# 4                     0                1              1            0
# ...                 ...              ...            ...          ...
# 9995                  0                0              0            1
# 9996                  0                0              0            1
# 9997                  0                0              1            0
# 9998                  1                0              0            1
# 9999                  0                0              1            0
#
# [10000 rows x 14 columns]

# %%
x = df.drop(columns = ['Exited'])
y = df['Exited']

# %%
sc = StandardScaler()

x = sc.fit_transform(x)

# %%
x
# Out:
# array([[-0.32622142,  0.29351742, -1.04175968, ..., -0.57380915,
#          1.09598752, -1.09598752],
#        [-0.44003595,  0.19816383, -1.38753759, ...,  1.74273971,
#          1.09598752, -1.09598752],
#        [-1.53679418,  0.29351742,  1.03290776, ..., -0.57380915,
#          1.09598752, -1.09598752],
#        ...,
#        [ 0.60498839, -0.27860412,  0.68712986, ..., -0.57380915,
#          1.09598752, -1.09598752],
#        [ 1.25683526,  0.29351742, -0.69598177, ..., -0.57380915,
#         -0.91241915,  0.91241915],
#        [ 1.46377078, -1.04143285, -0.35020386, ..., -0.57380915,
#          1.09598752, -1.09598752]])

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = 0.20, random_state=1)

# %%
ann = Sequential()

ann.add(Dense(units = 10, activation = 'relu'))
ann.add(Dense(units = 1, activation = 'sigmoid'))

ann.compile(optimizer = 'adadelta', loss = 'binary_crossentropy', metrics ='accuracy')

ann.fit(xtrain,ytrain,epochs = 100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.7572 - accuracy: 0.5416
# Epoch 2/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.7557 - accuracy: 0.5429
# Epoch 3/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.7543 - accuracy: 0.5436
# Epoch 4/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.7529 - accuracy: 0.5440
# Epoch 5/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.7514 - accuracy: 0.5452
# Epoch 6/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7500 - accuracy: 0.5460
# Epoch 7/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7485 - accuracy: 0.5468
# Epoch 8/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7471 - accuracy: 0.5474
# Epoch 9/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7456 - accuracy: 0.5484
# Epoch 10/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7441 - accuracy: 0.5499
# Epoch 11/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7427 - accuracy: 0.5506
# Epoch 12/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7413 - accuracy: 0.5511
# Epoch 13/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.7398 - accuracy: 0.5515
# Epoch 14/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7384 - accuracy: 0.5521
# Epoch 15/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.7370 - accuracy: 0.5529
# Epoch 16/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7356 - accuracy: 0.5541
# Epoch 17/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.7342 - accuracy: 0.5550
# Epoch 18/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7328 - accuracy: 0.5555
# Epoch 19/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.7314 - accuracy: 0.5560
# Epoch 20/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7300 - accuracy: 0.5575
# Epoch 21/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.7286 - accuracy: 0.5587
# Epoch 22/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7272 - accuracy: 0.5591
# Epoch 23/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7258 - accuracy: 0.5598
# Epoch 24/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7244 - accuracy: 0.5609
# Epoch 25/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7231 - accuracy: 0.5616
# Epoch 26/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.7217 - accuracy: 0.5629
# Epoch 27/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.7203 - accuracy: 0.5655
# Epoch 28/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.7190 - accuracy: 0.5667
# Epoch 29/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.7176 - accuracy: 0.5671
# Epoch 30/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.7163 - accuracy: 0.5686
# Epoch 31/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.7150 - accuracy: 0.5691
# Epoch 32/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7137 - accuracy: 0.5702
# Epoch 33/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7123 - accuracy: 0.5709
# Epoch 34/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7110 - accuracy: 0.5715
# Epoch 35/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7097 - accuracy: 0.5723
# Epoch 36/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7084 - accuracy: 0.5726
# Epoch 37/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7071 - accuracy: 0.5730
# Epoch 38/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7058 - accuracy: 0.5742
# Epoch 39/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7045 - accuracy: 0.5759
# Epoch 40/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7033 - accuracy: 0.5763
# Epoch 41/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.7020 - accuracy: 0.5771
# Epoch 42/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.7007 - accuracy: 0.5781
# Epoch 43/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6995 - accuracy: 0.5790
# Epoch 44/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6983 - accuracy: 0.5806
# Epoch 45/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6970 - accuracy: 0.5820
# Epoch 46/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6958 - accuracy: 0.5822
# Epoch 47/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6946 - accuracy: 0.5829
# Epoch 48/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.5835
# Epoch 49/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6922 - accuracy: 0.5844
# Epoch 50/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6910 - accuracy: 0.5854
# Epoch 51/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6898 - accuracy: 0.5866
# Epoch 52/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6886 - accuracy: 0.5874
# Epoch 53/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.6874 - accuracy: 0.5881
# Epoch 54/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.6862 - accuracy: 0.5890
# Epoch 55/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.6850 - accuracy: 0.5897
# Epoch 56/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.6839 - accuracy: 0.5906
# Epoch 57/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.6827 - accuracy: 0.5914
# Epoch 58/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6816 - accuracy: 0.5922
# Epoch 59/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6804 - accuracy: 0.5935
# Epoch 60/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6793 - accuracy: 0.5944
# Epoch 61/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6782 - accuracy: 0.5955
# Epoch 62/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6770 - accuracy: 0.5968
# Epoch 63/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6759 - accuracy: 0.5978
# Epoch 64/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6748 - accuracy: 0.5990
# Epoch 65/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6737 - accuracy: 0.5996
# Epoch 66/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6726 - accuracy: 0.6010
# Epoch 67/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6715 - accuracy: 0.6016
# Epoch 68/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6704 - accuracy: 0.6031
# Epoch 69/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6693 - accuracy: 0.6044
# Epoch 70/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6683 - accuracy: 0.6046
# Epoch 71/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6672 - accuracy: 0.6061
# Epoch 72/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6661 - accuracy: 0.6070
# Epoch 73/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6651 - accuracy: 0.6081
# Epoch 74/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6640 - accuracy: 0.6089
# Epoch 75/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6630 - accuracy: 0.6104
# Epoch 76/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6619 - accuracy: 0.6106
# Epoch 77/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6609 - accuracy: 0.6115
# Epoch 78/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6598 - accuracy: 0.6127
# Epoch 79/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.6588 - accuracy: 0.6133
# Epoch 80/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.6578 - accuracy: 0.6141
# Epoch 81/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.6568 - accuracy: 0.6148
# Epoch 82/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.6558 - accuracy: 0.6152
# Epoch 83/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6548 - accuracy: 0.6170
# Epoch 84/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6538 - accuracy: 0.6176
# Epoch 85/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6528 - accuracy: 0.6181
# Epoch 86/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6518 - accuracy: 0.6191
# Epoch 87/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6508 - accuracy: 0.6200
# Epoch 88/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6498 - accuracy: 0.6204
# Epoch 89/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6488 - accuracy: 0.6212
# Epoch 90/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6479 - accuracy: 0.6219
# Epoch 91/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6469 - accuracy: 0.6221
# Epoch 92/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6460 - accuracy: 0.6226
# Epoch 93/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6450 - accuracy: 0.6224
# Epoch 94/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6441 - accuracy: 0.6234
# Epoch 95/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6431 - accuracy: 0.6250
# Epoch 96/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6422 - accuracy: 0.6259
# Epoch 97/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6413 - accuracy: 0.6265
# Epoch 98/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6404 - accuracy: 0.6279
# Epoch 99/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.6395 - accuracy: 0.6288
# Epoch 100/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6385 - accuracy: 0.6295

# %%
ypred = ann.predict(xtest)
ypred = ypred > 0.5
ypred
# Out:
# 63/63 [==============================] - 0s 3ms/step
# array([[False],
#        [False],
#        [ True],
#        ...,
#        [ True],
#        [ True],
#        [False]])

# %%
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.68      0.75      1585
#            1       0.28      0.47      0.35       415
#
#     accuracy                           0.64      2000
#    macro avg       0.55      0.57      0.55      2000
# weighted avg       0.71      0.64      0.66      2000

# %%
ann.evaluate(xtrain,ytrain)
# Out:
# 250/250 [==============================] - 1s 1ms/step - loss: 0.6381 - accuracy: 0.6300
# [0.6380777359008789, 0.6299999952316284]

# %% [markdown]
# # Hyperparameter tuning

# %% [markdown]
# 1. Create the model: Start with an empty model.
# 2. Add layers: Depending on the number of layers (between 1 and 10), add layers to the model.
#   Each layer has:
#                   1. A number of units (8 to 128, increasing by 8).
#                   2.An activation function (can be 'relu', 'tanh', or 'sigmoid').
#                   3.The first layer also needs to know the input size (13 features).
# 3. Output layer: Add a final layer with 1 unit and 'sigmoid' activation, which is common for binary classification.
# 4. Compile the model: Choose an optimizer ('adam', 'rmsprop', or 'sgd'), use 'binary_crossentropy' as the loss function, and track 'accuracy'.
# 5. Return the model: The function returns the complete model.

# %%
list(range(8,128,8))
# Out:
# [8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120]

# %%
x.shape
# Out:
# (10000, 13)

# %%
def hyper(hp):
    model = Sequential()

    # Loop to add layers
    for i in range(hp.Int('num_layers', 1, 10)):
        units = hp.Int(f'units_{i}', 8, 128, 8)  # Number of units in the layer
        activation = hp.Choice(f'activation_{i}', ['relu', 'tanh', 'sigmoid'])  # Activation function

        if i == 0:
            # First layer needs input dimension
            model.add(Dense(units, activation=activation, input_dim=13))
        else:
            # Other layers
            model.add(Dense(units, activation=activation))

    # Output layer
    model.add(Dense(1, activation='sigmoid'))

    # Compile the model
    model.compile(
        optimizer=hp.Choice('optimizer', ['adam', 'rmsprop', 'sgd']),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
tuner = kf.RandomSearch(hyper,
                        objective = 'val_accuracy',
                        max_trials = 3)

# %%
tuner.search(xtrain,ytrain,epochs = 5, validation_data = (xtest,ytest))
# Out:
# Trial 3 Complete [00h 00m 12s]
# val_accuracy: 0.8370000123977661
#
# Best val_accuracy So Far: 0.8684999942779541
# Total elapsed time: 00h 00m 31s

# %%
tuner.get_best_hyperparameters()[0].values
# Out:
# {'num_layers': 7,
#  'units_0': 120,
#  'activation_0': 'relu',
#  'optimizer': 'rmsprop',
#  'units_1': 8,
#  'activation_1': 'relu',
#  'units_2': 8,
#  'activation_2': 'relu',
#  'units_3': 8,
#  'activation_3': 'relu',
#  'units_4': 8,
#  'activation_4': 'relu',
#  'units_5': 8,
#  'activation_5': 'relu',
#  'units_6': 8,
#  'activation_6': 'relu'}

# %%
x.shape

# %%
tuned_model = tuner.get_best_models(num_models=1)[0]

# %%
tuned_model.fit(xtrain,ytrain,epochs=25, validation_data=(xtest,ytest))
# Out:
# Epoch 1/25
# 250/250 [==============================] - 2s 8ms/step - loss: 0.2751 - accuracy: 0.8910 - val_loss: 0.3890 - val_accuracy: 0.8405
# Epoch 2/25
# 250/250 [==============================] - 2s 9ms/step - loss: 0.2723 - accuracy: 0.8923 - val_loss: 0.3945 - val_accuracy: 0.8430
# Epoch 3/25
# 250/250 [==============================] - 1s 6ms/step - loss: 0.2732 - accuracy: 0.8901 - val_loss: 0.3938 - val_accuracy: 0.8440
# Epoch 4/25
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2724 - accuracy: 0.8890 - val_loss: 0.3991 - val_accuracy: 0.8500
# Epoch 5/25
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2703 - accuracy: 0.8898 - val_loss: 0.4066 - val_accuracy: 0.8385
# Epoch 6/25
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2718 - accuracy: 0.8894 - val_loss: 0.4033 - val_accuracy: 0.8400
# Epoch 7/25
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2690 - accuracy: 0.8906 - val_loss: 0.4128 - val_accuracy: 0.8440
# Epoch 8/25
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2658 - accuracy: 0.8931 - val_loss: 0.4081 - val_accuracy: 0.8415
# Epoch 9/25
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2686 - accuracy: 0.8921 - val_loss: 0.4140 - val_accuracy: 0.8505
# Epoch 10/25
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2650 - accuracy: 0.8921 - val_loss: 0.4158 - val_accuracy: 0.8490
# Epoch 11/25
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2655 - accuracy: 0.8932 - val_loss: 0.4029 - val_accuracy: 0.8480
# Epoch 12/25
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2639 - accuracy: 0.8945 - val_loss: 0.4092 - val_accuracy: 0.8470
# Epoch 13/25
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2641 - accuracy: 0.8960 - val_loss: 0.4051 - val_accuracy: 0.8440
# Epoch 14/25
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2657 - accuracy: 0.8926 - val_loss: 0.4120 - val_accuracy: 0.8425
# Epoch 15/25
# 250/250 [==============================] - 1s 5ms/step - loss: 0.2614 - accuracy: 0.8953 - val_loss: 0.4080 - val_accuracy: 0.8530
# Epoch 16/25
# 250/250 [==============================] - 1s 5ms/step - loss: 0.2627 - accuracy: 0.8957 - val_loss: 0.4130 - val_accuracy: 0.8420
# Epoch 17/25
# 250/250 [==============================] - 1s 4ms/step - loss: 0.2588 - accuracy: 0.8965 - val_loss: 0.4113 - val_accuracy: 0.8450
# Epoch 18/25
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2589 - accuracy: 0.8951 - val_loss: 0.4237 - val_accuracy: 0.8425
# Epoch 19/25
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2566 - accuracy: 0.8979 - val_loss: 0.4246 - val_accuracy: 0.8435
# Epoch 20/25
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2575 - accuracy: 0.8964 - val_loss: 0.4430 - val_accuracy: 0.8475
# Epoch 21/25
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2570 - accuracy: 0.8996 - val_loss: 0.4435 - val_accuracy: 0.8445
# Epoch 22/25
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2557 - accuracy: 0.8976 - val_loss: 0.4432 - val_accuracy: 0.8355
# Epoch 23/25
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2579 - accuracy: 0.8970 - val_loss: 0.4301 - val_accuracy: 0.8325
# Epoch 24/25
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2546 - accuracy: 0.8999 - val_loss: 0.4304 - val_accuracy: 0.8395
# Epoch 25/25
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2533 - accuracy: 0.8975 - val_loss: 0.4331 - val_accuracy: 0.8380

# %%
tuned_model.evaluate(xtrain,ytrain)
# Out:
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2421 - accuracy: 0.9039
# [0.2420596033334732, 0.9038749933242798]

# %%
tuned_model.evaluate(xtest,ytest)
# Out:
# 63/63 [==============================] - 0s 3ms/step - loss: 0.4331 - accuracy: 0.8380
# [0.4331473410129547, 0.8379999995231628]
